# %%
## Creating new directory

import os

# %%
new_directory = "package"
os.mkdir(new_directory)

# %%
items = os.listdir()
print("Items in the current directory:")
for item in items:
    print(item)
# Out:
# Items in the current directory:
# 6.1-FileHandling.ipynb
# copy_example.txt
# example.txt
# 6.2-FilePath.ipynb
# package

# %%
## Check if path exists

path = "example.txt"

if os.path.exists(path):
    print(f"{path} exists")
else:
    print(f"{path} does not exist")
# Out:
# example.txt exists

# %%
## Check if the path is a file or directory

path = "example.txt"

if os.path.isfile(path):
    print(f"{path} is a file")
elif os.path.isdir(path):
    print(f"{path} is a directory")
else:
    print(f"{path} is neither a file nor a directory")
# Out:
# example.txt is a file

# %%
## Getting the absolute path
path = "example.txt"
absolute_path = os.path.abspath(path)
print(f"Absolute path of {path} is {absolute_path}")
# Out:
# Absolute path of example.txt is /Users/dharmasangeerani/Dharumaraj/github-repos/ds-ai-ml/python-programming-basics/file-handling/example.txt

# %%
# Out:
# olleh
