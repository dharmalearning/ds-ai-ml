# %% [markdown]
# # Standard Library Overview
#
# Python's standard library is a vast collection of modules and packages that commw inbuilt with python.

# %%
import array

array1 = array.array('i', [1, 2, 3])
print(array1)
# Out:
# array('i', [1, 2, 3])

# %%
import math

print(math.sqrt(4))
# Out:
# 2.0

# %%
import random
print(random.randint(1, 10))
print(random.choice([1, 2, 3, 4, 5]))
# Out:
# 6
# 4

# %%
import os
print(os.getcwd())
print(os.listdir('.'))
# Out:
# /Users/dharmasangeerani/Dharumaraj/github-repos/ds-ai-ml/python-programming-basics/modules-and-packages
# ['5.1-imports.ipynb', '5.2-Standardlibrary.ipynb', 'package']

# %%
# Data serialization

import json
data = {'name': 'Alice', 'age': 30}

json_str = json.dumps(data)
print(json_str)
print(type(json_str))
json_data = json.loads(json_str)
print(json_data)
print(type(json_data))
# Out:
# {"name": "Alice", "age": 30}
# <class 'str'>
# {'name': 'Alice', 'age': 30}
# <class 'dict'>

# %%
## CSV

import csv
with open('example.csv', mode = 'w', newline= '') as file:
    writer = csv.writer(file)
    writer.writerow(['Name', 'Age'])
    writer.writerow(['Alice', 30])
    writer.writerow(['Bob', 25])
with open('example.csv', mode = 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['Name', 'Age']
# ['Alice', '30']
# ['Bob', '25']

# %%
## time
import time
print(time.time())
time.sleep(1)
print(time.time())
# Out:
# 1746002070.699472
# 1746002071.7046971

# %%
## Regular Expressions

import re

pattern = r'\d+'
text = 'There are 123 apples and 456 oranges.'
matches = re.findall(pattern, text)
print(matches)
# Out:
# ['123', '456']

# %%
## datetime

from datetime import datetime, timedelta

now = datetime.now()
print(now)

yesterday = now - timedelta(days=1)
print(yesterday)
# Out:
# 2025-04-30 14:07:13.393708
# 2025-04-29 14:07:13.393708
