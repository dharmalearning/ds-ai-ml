# %% [markdown]
# # Syntax and Semantics in Python
# * Single line comments and multiline comments
# * Basic syntax and semantics
# * Basic syntax rules in python
# * Understanding semantics in Python
# * Common syntax errors and how to avoid them

# %% [markdown]
# ## Syntax
#
# Syntax is how you structure the code. It is basically set of rules that define the combinations of symbols that are considered to be correctly structured programs in a language.

# %% [markdown]
# ## Semantics
#
# Semantics referts to the menaing or interpretation of the symbols, characters and commands in a language. It is about what the code is supposed to do when it runs.

# %%
## Basic syntx rules in python
## Case sensistivity - Python is case sensitive

name="Dharma"
Name="Raj"
print(name)
print(Name)
# Out:
# Dharma
# Raj

# %% [markdown]
# ## Indendation
# Indentation in python is used to define the structure and heirarchy of the code. Unlike many other programming languages that uses braces {} to delimit blocks of code

# %%
## Identation
## Python uses indentation to define the scope of the code. Consistent use of spaces or tabs is important.

age = 32
if age > 30:
    print("Age is greater than 30")
print("This is outside the if block")
# Out:
# Age is greater than 30
# This is outside the if block

# %%
## Line continuation
## Python allows you to split a statement across multiple lines using the backslash (\) character.
total = 1 + 2 + 3 + 5 \
    + 6 + 7 + 8
print(total)
# Out:
# 32

# %%
## Multiple statements on a single line
x = 1; y = 2; z = x + y
print(x, y, z)
# Out:
# 1 2 3

# %% [markdown]
# ## Type inferencing

# %%
## Type inferencing
varibale=10
print(type(varibale))

## chaingg the type of the variable. During the runtime, the type of the variable can be changed.
varibale="Dharma"
print(type(varibale))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# # Vairbales
#
# Varibales are fundamental elements in programming used to store data that can be referenced and manipulated in a program. In Python vriables are created when you assign a value to them and they do not need explicit declaration to reserve memory space. The declaration happens automatically when you assing a value to them
#
# * Intriduction to variables
# * Declaring and Assigning variables
# * Naming  Conventions
# * Understanding Variable Types
# * Type checking and conversion
# * Dunamic Typing

# %%
## Declaring and assigning variables
## In Python, you can declare and assign variables without specifying their type.
## You can also assign multiple variables in a single line.
## Python supports dynamic typing, meaning you don't need to declare the type of a variable explicitly.
## You can assign multiple variables in a single line.

age = 32
height = 6.1
name = "Dharma"
is_student = True

print("age : ", age )
print("height : ", height)
print("name : ", name )
print("is_student : ", is_student)
# Out:
# age :  32
# height :  6.1
# name :  Dharma
# is_student :  True

# %%
## Naming conventions
## Variable names can contain letters, numbers, and underscores, but cannot start with a number.
## Variable names are case-sensitive, so "myVar" and "myvar" are different variables.
first_name = "Dharma" ## Valid variable name
firstName = "Dharma" ## Valid variable name
## first-name = "Dharma" ## Invalid variable name (contains a hyphen)
## first name = "Dharma" ## Invalid variable name (contains a space)

# %%
## Type conversion
age = 25
print(type(age))  # Output: <class 'int'>
age_str = str(age)  # Convert integer to string
print(type(age_str))  # Output: <class 'str'>
# Out:
# <class 'int'>
# <class 'str'>

# %%
## User input
age = input("Enter your age: ")
print("Your age is: ", type(age))
age = int(age)  # Convert string to integer
print("Your age is: ", type(age))
# Out:
# Your age is:  <class 'str'>
# Your age is:  <class 'int'>
